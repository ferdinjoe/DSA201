# %%
# !pip install pandas

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.0.5

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.7.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# machine          : AMD64
# processor        : Intel64 Family 6 Model 165 Stepping 2, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : None.None
#
# pandas           : 1.0.5
# numpy            : 1.18.5
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.0.2
# setuptools       : 46.4.0.post20200518
# Cython           : 0.29.14
# pytest           : 5.4.3
# hypothesis       : None
# sphinx           : 3.1.2
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# IPython          : 7.16.1
# pandas_datareader: None
# bs4              : 4.9.1
# bottleneck       : None
# ...

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}
purchase=pd.DataFrame(data)
purchase
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchase=pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchase
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
#Locate a customer
purchase.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchase.loc['Lily']
# Out:
# apples     0
# oranges    7
# Name: Lily, dtype: int64

# %%
url = 'https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/purchases.csv'
df = pd.read_csv(url, error_bad_lines=False)
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
df = pd.read_csv('IMDB Dataset.csv', index_col=0)
df
# Out:
#                                                    sentiment
# review
# One of the other reviewers has mentioned that a...  positive
# A wonderful little production. <br /><br />The ...  positive
# I thought this was a wonderful way to spend tim...  positive
# Basically there's a family where a little boy (...  negative
# Petter Mattei's "Love in the Time of Money" is ...  positive
# ...                                                      ...
# I thought this movie did a down right good job....  positive
# Bad plot, bad dialogue, bad acting, idiotic dir...  negative
# I am a Catholic taught in parochial elementary ...  negative
# I'm going to have to disagree with the previous...  negative
# No one expects the Star Trek movies to be high ...  negative
#
# [50000 rows x 1 columns]

# %%
df=pd.read_csv('C:/Users/Admin/IMDB Dataset.csv')
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
url = 'https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/purchases.csv'
df = pd.read_csv(url, error_bad_lines=False)
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
url = 'https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/purchases.csv'
df = pd.read_csv(url, error_bad_lines=False, index_col=0)
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
#Convert to JSON
df.to_json('new_purchases.json')

# %%
df = pd.read_json('new_purchases.json')
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
movies_df = pd.read_csv("IMDB movies.csv", index_col="title")
movies_df
# Out:
#                                                    imdb_title_id  \
# title
# The Story of the Kelly Gang                            tt0000574
# Den sorte drøm                                         tt0001892
# Cleopatra                                              tt0002101
# L'Inferno                                              tt0002130
# From the Manger to the Cross; or, Jesus of Naza...     tt0002199
# ...                                                          ...
# Jessie                                                 tt9903716
# Ottam                                                  tt9905412
# Pengalila                                              tt9905462
# Padmavyuhathile Abhimanyu                              tt9911774
# Sokagin Çocuklari                                      tt9914286
#
#                                                                                        original_title  \
# title
# ...

# %%
movies_df.head()
# Out:
#                                                    imdb_title_id  \
# title
# The Story of the Kelly Gang                            tt0000574
# Den sorte drøm                                         tt0001892
# Cleopatra                                              tt0002101
# L'Inferno                                              tt0002130
# From the Manger to the Cross; or, Jesus of Naza...     tt0002199
#
#                                                                                        original_title  \
# title
# The Story of the Kelly Gang                                               The Story of the Kelly Gang
# Den sorte drøm                                                                         Den sorte drøm
# Cleopatra                                                                                   Cleopatra
# L'Inferno                                                                                   L'Inferno
# ...

# %%
#List last two data
movies_df.tail(2)
# Out:
#                           imdb_title_id             original_title  year  \
# title
# Padmavyuhathile Abhimanyu     tt9911774  Padmavyuhathile Abhimanyu  2019
# Sokagin Çocuklari             tt9914286          Sokagin Çocuklari  2019
#
#                           date_published          genre  duration country  \
# title
# Padmavyuhathile Abhimanyu     2019-03-08          Drama       130   India
# Sokagin Çocuklari             2019-03-15  Drama, Family        98  Turkey
#
#                             language           director  \
# title
# Padmavyuhathile Abhimanyu  Malayalam    Vineesh Aaradya
# Sokagin Çocuklari            Turkish  Ahmet Faik Akinci
#
#                                                      writer  ...  \
# title                                                        ...
# Padmavyuhathile Abhimanyu  Vineesh Aaradya, Vineesh Aaradya  ...
# Sokagin Çocuklari            Ahmet Faik Akinci, Kasim Uçkan  ...
#
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81273 entries, The Story of the Kelly Gang to Sokagin Çocuklari
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          81273 non-null  object
#  1   original_title         81273 non-null  object
#  2   year                   81273 non-null  int64
#  3   date_published         81273 non-null  object
#  4   genre                  81273 non-null  object
#  5   duration               81273 non-null  int64
#  6   country                81234 non-null  object
#  7   language               80518 non-null  object
#  8   director               81200 non-null  object
#  9   writer                 79780 non-null  object
#  10  production_company     76948 non-null  object
#  11  actors                 81207 non-null  object
#  12  description            78843 non-null  object
#  13  avg_vote               81273 non-null  float64
# ...

# %%
movies_df.shape
# Out:
# (81273, 21)

# %%
temp_df = movies_df.append(movies_df)

temp_df.shape
# Out:
# (162546, 21)

# %%
temp_df = temp_df.drop_duplicates()

temp_df.shape
# Out:
# (81273, 21)

# %%
temp_df.drop_duplicates(inplace=True)
print(temp_df.shape)
temp_df.head(2)
# Out:
# (81273, 21)
#                             imdb_title_id               original_title  year  \
# title
# The Story of the Kelly Gang     tt0000574  The Story of the Kelly Gang  1906
# Den sorte drøm                  tt0001892               Den sorte drøm  1911
#
#                             date_published                    genre  duration  \
# title
# The Story of the Kelly Gang     1906-12-26  Biography, Crime, Drama        70
# Den sorte drøm                  1911-08-19                    Drama        53
#
#                                       country language      director  \
# title
# The Story of the Kelly Gang         Australia      NaN  Charles Tait
# Den sorte drøm               Germany, Denmark      NaN     Urban Gad
#
#                                                             writer  ...  \
# title                                                               ...
# The Story of the Kelly Gang                           Charles Tait  ...
# ...

# %%
movies_df.columns
# Out:
# Index(['imdb_title_id', 'original_title', 'year', 'date_published', 'genre',
#        'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movies_df.rename(columns={
        'imdb_title_id': 'Title_ID', 
        'original_title': 'Title'
    }, inplace=True)


movies_df.columns
# Out:
# Index(['Title_ID', 'Title', 'year', 'date_published', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'budget',
#        'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
#Change the attributes to lowercase
movies_df.columns = [col.lower() for col in movies_df]

movies_df.columns
# Out:
# Index(['title_id', 'title', 'year', 'date_published', 'genre', 'duration',
#        'country', 'language', 'director', 'writer', 'production_company',
#        'actors', 'description', 'avg_vote', 'votes', 'budget',
#        'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
movies_df.columns = [col.upper() for col in movies_df]

movies_df.columns
# Out:
# Index(['TITLE_ID', 'TITLE', 'YEAR', 'DATE_PUBLISHED', 'GENRE', 'DURATION',
#        'COUNTRY', 'LANGUAGE', 'DIRECTOR', 'WRITER', 'PRODUCTION_COMPANY',
#        'ACTORS', 'DESCRIPTION', 'AVG_VOTE', 'VOTES', 'BUDGET',
#        'USA_GROSS_INCOME', 'WORLWIDE_GROSS_INCOME', 'METASCORE',
#        'REVIEWS_FROM_USERS', 'REVIEWS_FROM_CRITICS'],
#       dtype='object')

# %%
#Number of nulls in each column
movies_df.isnull()
# Out:
#                                                     TITLE_ID  TITLE   YEAR  \
# title
# The Story of the Kelly Gang                            False  False  False
# Den sorte drøm                                         False  False  False
# Cleopatra                                              False  False  False
# L'Inferno                                              False  False  False
# From the Manger to the Cross; or, Jesus of Naza...     False  False  False
# ...                                                      ...    ...    ...
# Jessie                                                 False  False  False
# Ottam                                                  False  False  False
# Pengalila                                              False  False  False
# Padmavyuhathile Abhimanyu                              False  False  False
# Sokagin Çocuklari                                      False  False  False
#
# ...

# %%
movies_df.isnull().sum()
# Out:
# TITLE_ID                     0
# TITLE                        0
# YEAR                         0
# DATE_PUBLISHED               0
# GENRE                        0
# DURATION                     0
# COUNTRY                     39
# LANGUAGE                   755
# DIRECTOR                    73
# WRITER                    1493
# PRODUCTION_COMPANY        4325
# ACTORS                      66
# DESCRIPTION               2430
# AVG_VOTE                     0
# VOTES                        0
# BUDGET                   58469
# USA_GROSS_INCOME         66179
# WORLWIDE_GROSS_INCOME    51381
# METASCORE                68551
# REVIEWS_FROM_USERS        7077
# REVIEWS_FROM_CRITICS     10987
# dtype: int64

# %%
#Remove null values
movies_df.dropna()
# Out:
#                                   TITLE_ID                            TITLE  \
# title
# Metropolis                       tt0017136                       Metropolis
# City Lights                      tt0021749                      City Lights
# Modern Times                     tt0027977                     Modern Times
# Snow White and the Seven Dwarfs  tt0029583  Snow White and the Seven Dwarfs
# Gone with the Wind               tt0031381               Gone with the Wind
# ...                                    ...                              ...
# Midsommar                        tt8772262                        Midsommar
# Unplanned                        tt9024106                        Unplanned
# Cold Blood Legacy                tt9082020                Cold Blood Legacy
# Playing with Fire                tt9134216                Playing with Fire
# Jexi                             tt9354944                             Jexi
#
# ...

# %%
movies_df.dropna(axis=1)
# Out:
#                                                      TITLE_ID  \
# title
# The Story of the Kelly Gang                         tt0000574
# Den sorte drøm                                      tt0001892
# Cleopatra                                           tt0002101
# L'Inferno                                           tt0002130
# From the Manger to the Cross; or, Jesus of Naza...  tt0002199
# ...                                                       ...
# Jessie                                              tt9903716
# Ottam                                               tt9905412
# Pengalila                                           tt9905462
# Padmavyuhathile Abhimanyu                           tt9911774
# Sokagin Çocuklari                                   tt9914286
#
#                                                                                                 TITLE  \
# title
# The Story of the Kelly Gang                                               The Story of the Kelly Gang
# ...

# %%
duration = movies_df['DURATION']
duration
# Out:
# title
# The Story of the Kelly Gang                             70
# Den sorte drøm                                          53
# Cleopatra                                              100
# L'Inferno                                               68
# From the Manger to the Cross; or, Jesus of Nazareth     60
#                                                       ...
# Jessie                                                 106
# Ottam                                                  120
# Pengalila                                              111
# Padmavyuhathile Abhimanyu                              130
# Sokagin Çocuklari                                       98
# Name: DURATION, Length: 81273, dtype: int64

# %%
duration.head()
# Out:
# title
# The Story of the Kelly Gang                             70
# Den sorte drøm                                          53
# Cleopatra                                              100
# L'Inferno                                               68
# From the Manger to the Cross; or, Jesus of Nazareth     60
# Name: DURATION, dtype: int64

# %%
durationmean=duration.mean()
durationmean
# Out:
# 100.56598132221033

# %%
duration.fillna(durationmean, inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# TITLE_ID                     0
# TITLE                        0
# YEAR                         0
# DATE_PUBLISHED               0
# GENRE                        0
# DURATION                     0
# COUNTRY                     39
# LANGUAGE                   755
# DIRECTOR                    73
# WRITER                    1493
# PRODUCTION_COMPANY        4325
# ACTORS                      66
# DESCRIPTION               2430
# AVG_VOTE                     0
# VOTES                        0
# BUDGET                   58469
# USA_GROSS_INCOME         66179
# WORLWIDE_GROSS_INCOME    51381
# METASCORE                68551
# REVIEWS_FROM_USERS        7077
# REVIEWS_FROM_CRITICS     10987
# dtype: int64

# %%
#Summary of continuos variables
movies_df.describe()
# Out:
#                YEAR      DURATION      AVG_VOTE         VOTES     METASCORE  \
# count  81273.000000  81273.000000  81273.000000  8.127300e+04  12722.000000
# mean    1993.007210    100.565981      5.926587  9.421771e+03     55.762695
# std       23.992284     25.320189      1.243315  5.220245e+04     17.757453
# min     1906.000000     40.000000      1.000000  9.900000e+01      1.000000
# 25%     1979.000000     88.000000      5.200000  2.060000e+02     43.000000
# 50%     2002.000000     96.000000      6.100000  4.950000e+02     56.000000
# 75%     2012.000000    108.000000      6.800000  1.865000e+03     69.000000
# max     2019.000000   3360.000000     10.000000  2.159628e+06    100.000000
#
#        REVIEWS_FROM_USERS  REVIEWS_FROM_CRITICS
# count        74196.000000          70286.000000
# mean            43.753194             27.992758
# std            159.903568             58.708764
# min              1.000000              1.000000
# ...

# %%
desc=movies_df['YEAR'].describe()
desc
# Out:
# count    81273.000000
# mean      1993.007210
# std         23.992284
# min       1906.000000
# 25%       1979.000000
# 50%       2002.000000
# 75%       2012.000000
# max       2019.000000
# Name: YEAR, dtype: float64

# %%
desc.min
# Out:
# <bound method Series.min of count    81273.000000
# mean      1993.007210
# std         23.992284
# min       1906.000000
# 25%       1979.000000
# 50%       2002.000000
# 75%       2012.000000
# max       2019.000000
# Name: YEAR, dtype: float64>

# %%
movies_df.corr()
# Out:
#                           YEAR  DURATION  AVG_VOTE     VOTES  METASCORE  \
# YEAR                  1.000000  0.150164 -0.213843  0.061409  -0.176244
# DURATION              0.150164  1.000000  0.221752  0.111327   0.217760
# AVG_VOTE             -0.213843  0.221752  1.000000  0.164838   0.692214
# VOTES                 0.061409  0.111327  0.164838  1.000000   0.196126
# METASCORE            -0.176244  0.217760  0.692214  0.196126   1.000000
# REVIEWS_FROM_USERS    0.068079  0.117187  0.142879  0.792243   0.128114
# REVIEWS_FROM_CRITICS  0.145183  0.132651  0.198265  0.674826   0.239111
#
#                       REVIEWS_FROM_USERS  REVIEWS_FROM_CRITICS
# YEAR                            0.068079              0.145183
# DURATION                        0.117187              0.132651
# AVG_VOTE                        0.142879              0.198265
# VOTES                           0.792243              0.674826
# METASCORE                       0.128114              0.239111
# ...

# %%
prom = movies_df.iloc[1]
prom
# Out:
# TITLE_ID                                                         tt0001892
# TITLE                                                       Den sorte drøm
# YEAR                                                                  1911
# DATE_PUBLISHED                                                  1911-08-19
# GENRE                                                                Drama
# DURATION                                                                53
# COUNTRY                                                   Germany, Denmark
# LANGUAGE                                                               NaN
# DIRECTOR                                                         Urban Gad
# WRITER                               Urban Gad, Gebhard Schätzler-Perasini
# PRODUCTION_COMPANY                                                Fotorama
# ACTORS                   Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# ...

# %%
movie_subset = movies_df.loc['Atlantis':'Cabiria']

movie_subset = movies_df.iloc[1:4]

movie_subset
# Out:
#                  TITLE_ID           TITLE  YEAR DATE_PUBLISHED  \
# title
# Den sorte drøm  tt0001892  Den sorte drøm  1911     1911-08-19
# Cleopatra       tt0002101       Cleopatra  1912     1912-11-13
# L'Inferno       tt0002130       L'Inferno  1911     1911-03-06
#
#                                     GENRE  DURATION           COUNTRY  \
# title
# Den sorte drøm                      Drama        53  Germany, Denmark
# Cleopatra                  Drama, History       100               USA
# L'Inferno       Adventure, Drama, Fantasy        68             Italy
#
#                LANGUAGE                             DIRECTOR  \
# title
# Den sorte drøm      NaN                            Urban Gad
# Cleopatra       English                   Charles L. Gaskill
# L'Inferno       Italian  Francesco Bertolini, Adolfo Padovan
#
#                                                WRITER  ...  \
# title                                                  ...
# ...

# %%
condition = (movies_df['DIRECTOR'] == "Louis Feuillade")

condition.head()
# Out:
# title
# The Story of the Kelly Gang                            False
# Den sorte drøm                                         False
# Cleopatra                                              False
# L'Inferno                                              False
# From the Manger to the Cross; or, Jesus of Nazareth    False
# Name: DIRECTOR, dtype: bool

# %%
movies_df[movies_df['DIRECTOR'] == "Louis Feuillade"].head()
# Out:
#                                         TITLE_ID  \
# title
# Fantômas - À l'ombre de la guillotine  tt0002844
# Juve contre Fantômas                   tt0003037
# Le mort qui tue                        tt0003165
# Fantômas contre Fantômas               tt0003930
# Le faux magistrat                      tt0003952
#
#                                                                        TITLE  \
# title
# Fantômas - À l'ombre de la guillotine  Fantômas - À l'ombre de la guillotine
# Juve contre Fantômas                                    Juve contre Fantômas
# Le mort qui tue                                              Le mort qui tue
# Fantômas contre Fantômas                            Fantômas contre Fantômas
# Le faux magistrat                                          Le faux magistrat
#
#                                        YEAR DATE_PUBLISHED  \
# title
# Fantômas - À l'ombre de la guillotine  1913     1913-05-12
# Juve contre Fantômas                   1913     1913-09-08
# ...

# %%
movies_df[movies_df['DURATION'] >= 70].head(3)
# Out:
#                               TITLE_ID                        TITLE  YEAR  \
# title
# The Story of the Kelly Gang  tt0000574  The Story of the Kelly Gang  1906
# Cleopatra                    tt0002101                    Cleopatra  1912
# Madame DuBarry               tt0002423               Madame DuBarry  1919
#
#                             DATE_PUBLISHED                      GENRE  \
# title
# The Story of the Kelly Gang     1906-12-26    Biography, Crime, Drama
# Cleopatra                       1912-11-13             Drama, History
# Madame DuBarry                  1919-11-26  Biography, Drama, Romance
#
#                              DURATION    COUNTRY LANGUAGE            DIRECTOR  \
# title
# The Story of the Kelly Gang        70  Australia      NaN        Charles Tait
# Cleopatra                         100        USA  English  Charles L. Gaskill
# Madame DuBarry                     85    Germany   German      Ernst Lubitsch
#
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81273 entries, The Story of the Kelly Gang to Sokagin Çocuklari
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   TITLE_ID               81273 non-null  object
#  1   TITLE                  81273 non-null  object
#  2   YEAR                   81273 non-null  int64
#  3   DATE_PUBLISHED         81273 non-null  object
#  4   GENRE                  81273 non-null  object
#  5   DURATION               81273 non-null  int64
#  6   COUNTRY                81234 non-null  object
#  7   LANGUAGE               80518 non-null  object
#  8   DIRECTOR               81200 non-null  object
#  9   WRITER                 79780 non-null  object
#  10  PRODUCTION_COMPANY     76948 non-null  object
#  11  ACTORS                 81207 non-null  object
#  12  DESCRIPTION            78843 non-null  object
#  13  AVG_VOTE               81273 non-null  float64
# ...

# %%
movies_df[(movies_df['DIRECTOR'] == 'Charles Tait') | (movies_df['DIRECTOR'] == 'Christopher Nolan')].head()
# Out:
#                               TITLE_ID                        TITLE  YEAR  \
# title
# The Story of the Kelly Gang  tt0000574  The Story of the Kelly Gang  1906
# Following                    tt0154506                    Following  1998
# Memento                      tt0209144                      Memento  2000
# Insomnia                     tt0278504                     Insomnia  2002
# Batman Begins                tt0372784                Batman Begins  2005
#
#                             DATE_PUBLISHED                     GENRE  \
# title
# The Story of the Kelly Gang     1906-12-26   Biography, Crime, Drama
# Following                       1999-11-05  Crime, Mystery, Thriller
# Memento                         2000-10-27         Mystery, Thriller
# Insomnia                        2002-08-30  Drama, Mystery, Thriller
# Batman Begins                   2005-06-16         Action, Adventure
#
#                              DURATION    COUNTRY                 LANGUAGE  \
# title
# ...

# %%
#Read Excel
#!pip install xlrd
pd.read_excel('Pandasdemo.xlsx', index_col=None, header=None)
# Out:
#      0      1
# 0  Day  Value
# 1    1     10
# 2    2     23
# 3    3     45
# 4    4     56

# %%
pd.read_excel(open('Pandasdemo.xlsx', 'rb'),sheet_name='Sheet1')
# Out:
#    Day  Value
# 0    1     10
# 1    2     23
# 2    3     45
# 3    4     56
